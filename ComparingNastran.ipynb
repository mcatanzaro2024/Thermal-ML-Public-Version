# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import GridSimulator
HeatSimulation = GridSimulator.ClassHeatSimulation()

Nastran = pd.read_csv('230128 Reference Case for Verification (Cast Iron, Convection on 1-side).csv')

Nastran
# Out:
#     Set ID  Set Value             Set Title  Study ID  Vector ID        Title  \
# 0        1     0.0000        Case 1 Time 0.         1         31  Temperature
# 1        2    10.0000       Case 1 Time 10.         1         31  Temperature
# 2        3    20.0000       Case 1 Time 20.         1         31  Temperature
# 3        4    22.5000      Case 1 Time 22.5         1         31  Temperature
# 4        5    23.1250    Case 1 Time 23.125         1         31  Temperature
# 5        6    23.4375   Case 1 Time 23.4375         1         31  Temperature
# 6        7    24.6875   Case 1 Time 24.6875         1         31  Temperature
# 7        8    25.9375   Case 1 Time 25.9375         1         31  Temperature
# 8        9    27.1875   Case 1 Time 27.1875         1         31  Temperature
# 9       10    28.4375   Case 1 Time 28.4375         1         31  Temperature
# 10      11    29.6875   Case 1 Time 29.6875         1         31  Temperature
# ...

# %%
Line = 19
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
Temp
# Out:
# array([200, 187.1462, 174.4031, 161.8742, 149.6392, 137.795, 126.42,
#        115.5869, 105.3605, 95.79371, 86.92626, 78.78423000000001,
#        71.37961, 64.71041, 58.761359999999996, 53.50529, 48.90504,
#        44.91558, 41.48645, 38.56394, 36.09332, 34.02061, 32.29416,
#        30.86569, 29.69108, 28.73071, 27.94963, 27.317429999999998,
#        26.807990000000004, 26.399140000000003, 26.072229999999998,
#        25.811729999999997, 25.604779999999998, 25.44086, 25.31136,
#        25.2093, 25.12905, 25.06609, 25.0168, 24.978289999999998, 24.94827,
#        24.92494, 24.90687, 24.89293, 24.882270000000002, 24.87419,
#        24.86819, 24.863889999999998, 24.861, 24.85933], dtype=object)

# %%
#type(Temp)
# Out:
# numpy.ndarray

# %%
#Temp.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-4aceb0430a43> in <module>
# ----> 1 Temp.to_numpy()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'

# %%
plt.plot(X,Temp, label="Nastran")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.legend()
plt.show()

# %%
HeatSimulation.SetSize(.005,.025)
HeatSimulation.SetNodes(4,.10)
HeatSimulation.SetMaterialProperties(7753,486,36)
HeatSimulation.SetConvectionProperties(4,25)
HeatSimulation.EnableSurfaceHeatTransfer(True)
HeatSimulation.SetHeatSource(200)
HeatSimulation.SetInitalTemp(25)
HeatSimulation.SetTimeIncrement(TimeSim/10)

# %%
HeatSimulation.AllTemp
# Out:
#         Time  Heater      Node1      Node2      Node3      Node4  Convection
# 0    0.00000   200.0  25.000000  25.000000  25.000000  25.000000        25.0
# 1    2.96875   200.0  32.941968  25.000000  25.000000  25.000000        25.0
# 2    5.93750   200.0  40.159075  25.360428  25.000000  25.000000        25.0
# 3    8.90625   200.0  46.733837  26.015491  25.016357  25.000000        25.0
# 4   11.87500   200.0  52.738252  26.909889  25.060950  25.001485        25.0
# 5   14.84375   200.0  58.235236  27.997177  25.142130  25.006881        25.0
# 6   17.81250   200.0  63.279857  29.238380  25.265490  25.019154        25.0
# 7   20.78125   200.0  67.920386  30.600835  25.434477  25.041503        25.0
# 8   23.75000   200.0  72.199208  32.057209  25.650887  25.077150        25.0
# 9   26.71875   200.0  76.153598  33.584665  25.915257  25.129187        25.0
# 10  29.68750   200.0  79.816393  35.164170  26.227180  25.200470        25.0

# %%
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(HeatSimulation.AllTemp)-1,'Set Value']))
HeatSimulation.TimeInc
# Out:
# 5.115059221658206

# %%
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]

# %%
MyTemp
# Out:
# array([ 7.92094130e+04, -6.85730429e+04,  2.01683160e+04,  2.50000000e+01])

# %%
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.legend()
plt.show()

# %% [markdown]
# Results are below, comparing distance and tempature at a certain time

# %%
HeatSimulation.SetSize(.005,.025)
HeatSimulation.SetNodes(4,.10)
HeatSimulation.SetMaterialProperties(7753,486,36)
HeatSimulation.SetConvectionProperties(4,25)
HeatSimulation.EnableSurfaceHeatTransfer(True)
HeatSimulation.SetHeatSource(200)
HeatSimulation.SetInitalTemp(25)

# %%
Line = 5
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %%
Line = 10
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %%
Line = 15
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %%
Line = 20
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %%
Line = 25
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %%
Line = 30
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %%
Line = 35
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %%
Line = 37
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:6].to_numpy()
MyX = [12.5,12.5+25,12.5+50,12.5+75]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 200)
plt.legend()
plt.show()
# Out:
# 2065.0

# %% [markdown]
# With double my nodes

# %%
HeatSimulation.SetSize(.005,.025)
HeatSimulation.SetNodes(8,.10)
HeatSimulation.SetMaterialProperties(7753,486,36)
HeatSimulation.SetConvectionProperties(4,25)
HeatSimulation.EnableSurfaceHeatTransfer(True)
HeatSimulation.SetHeatSource(200)
HeatSimulation.SetInitalTemp(25)


Line = 5
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()

Line = 10
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()

Line = 15
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()

Line = 20
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()

Line = 25
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()

Line = 30
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()

Line = 35
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()

Line = 37
TimeSim = Nastran.loc[Line,'Set Value']
Temp = Nastran.iloc[Line,6:56].to_numpy()
X = np.linspace(0,100,50)
HeatSimulation.SetTimeIncrement(TimeSim/(Nastran.loc[len(Nastran)-1,'Set Value']))
HeatSimulation.GetTempatureAtNodeAtTime(0,TimeSim,4)
MyTemp = HeatSimulation.AllTemp.iloc[(len(HeatSimulation.AllTemp)-1),2:10].to_numpy()
MyX = [6.25,6.25+12.5,6.25+25,6.25+25+12.5,6.25+50,6.25+50++12.5,6.25+75,6.25+75+12.5]
plt.plot(X,Temp, label="Nastran")
plt.plot(MyX,MyTemp, label="MyModel",marker= "p")
plt.xlabel("Distance(mm)")
plt.ylabel("Temperature (C)")
plt.title('Time ' + str(TimeSim))
plt.ylim(20, 205)
plt.legend()
plt.show()
# Out:
# 2065.0
# 2065.0
# 2065.0
# 2065.0
# 2065.0
# 2065.0
# 2065.0
# 2065.0
